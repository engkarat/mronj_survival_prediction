# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f_path = './All-DATA-MRONJ-Deep-learning_2023-09-18.csv'
df = pd.read_csv(f_path)
df
# Out:
#       Gender Age  Age_range  MRONJ_related_Disease  \
# 0          1  76          2                      1
# 1          1  80          2                      1
# 2          1  69          2                      1
# 3          2  65          2                      1
# 4          1  82          2                      1
# ...      ...  ..        ...                    ...
# 5300       2  71          2                      1
# 5301       2  74          2                      2
# 5302       2  74          2                      2
# 5303       1  69          2                      1
# 5304       2  74          2                      2
#
#       MRONJ_related_Disease_separate  Underlying_Disease  \
# 0                                  1                   0
# 1                                  1                   0
# 2                                  1                   0
# 3                                  1                   0
# 4                                  1                   0
# ...

# %%
age = df['Age'].apply(lambda x: -1 if x == '-' else x).astype('int')
plt.figure(figsize=[10, 6])
plt.hist(age)
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
age_clean = age[age > 0]
np.min(age_clean), np.max(age_clean), np.median(age_clean), np.mean(age_clean)
# Out:
# (3, 104, 75.0, 74.32692307692308)

# %%
len(df[df['MRONJ'] == 1]), len(df), len(df[df['MRONJ'] == 1]) / len(df)
# Out:
# (81, 5305, 0.015268614514608859)
