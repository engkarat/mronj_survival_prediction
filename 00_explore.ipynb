# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f_path = 'itkmitl/dent_research/All-DATA-MRONJ-Deep-learning.xlsx'
df = pd.read_excel(f_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5305 entries, 0 to 5304
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 5305 non-null   int64
#  1   Age                                    81 non-null     float64
#  2   Age range                              5305 non-null   int64
#  3   MRONJ related Disease                  5305 non-null   int64
#  4   MRONJ related Disease (separate)       5305 non-null   int64
#  5   Underlying_Disease                     5305 non-null   int64
#  6   Underlying_Disease (separate)          5305 non-null   int64
#  7   Antiresorptive drug (BPIV/BPOral/DIV)  5305 non-null   int64
#  8   SteroidDrug(IV/Oral)                   5305 non-null   int64
#  9   ImmunosuppressiveDrug(Yes/NO)          5305 non-null   int64
#  10  Calcium                                5305 non-null   int64
# ...

# %%
df
# Out:
#       Gender   Age  Age range  MRONJ related Disease  \
# 0          1  76.0          2                      1
# 1          1  80.0          2                      1
# 2          1  69.0          2                      1
# 3          2  65.0          2                      1
# 4          1  82.0          2                      1
# ...      ...   ...        ...                    ...
# 5300       2   NaN          2                      1
# 5301       2   NaN          2                      2
# 5302       2   NaN          2                      2
# 5303       1   NaN          2                      1
# 5304       2   NaN          1                      2
#
#       MRONJ related Disease (separate)  Underlying_Disease  \
# 0                                    1                   0
# 1                                    1                   0
# 2                                    1                   0
# 3                                    1                   0
# ...

# %%
cols = [
    'Gender', 'Age range', 'MRONJ related Disease', 'MRONJ related Disease (separate)',
    'Underlying_Disease', 'Underlying_Disease (separate)', 'Antiresorptive drug (BPIV/BPOral/DIV)',
    'SteroidDrug(IV/Oral)', 'ImmunosuppressiveDrug(Yes/NO)', 'Calcium', 'Location', 'DentalHistory',
]
df[cols]
# Out:
#       Gender  Age range  MRONJ related Disease  \
# 0          1          2                      1
# 1          1          2                      1
# 2          1          2                      1
# 3          2          2                      1
# 4          1          2                      1
# ...      ...        ...                    ...
# 5300       2          2                      1
# 5301       2          2                      2
# 5302       2          2                      2
# 5303       1          2                      1
# 5304       2          1                      2
#
#       MRONJ related Disease (separate)  Underlying_Disease  \
# 0                                    1                   0
# 1                                    1                   0
# 2                                    1                   0
# 3                                    1                   0
# 4                                    1                   0
# ...
